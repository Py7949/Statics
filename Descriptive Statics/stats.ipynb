# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv('D:\Statics\students_marks_10_named.csv')

# %%
df.head()
# Out:
#   Rollno    Name  Data Structure  Mathematics  Operating System
# 0  R1000  Ananya              80           69                56
# 1  R1001    Ravi              74           78                72
# 2  R1002   Priya              67           65                86
# 3  R1003    Amit              90           98                57
# 4  R1004   Sneha              80           96                77

# %%
df['Rollno']= df['Rollno'].str.replace('R','').astype(int)

# %%
df.describe()
# Out:
#            Rollno  Data Structure  Mathematics  Operating System
# count    10.00000       10.000000    10.000000         10.000000
# mean   1004.50000       71.700000    73.200000         67.200000
# std       3.02765       16.438775    13.894843         14.905629
# min    1000.00000       42.000000    55.000000         43.000000
# 25%    1002.25000       64.000000    66.000000         56.250000
# 50%    1004.50000       77.000000    69.500000         71.500000
# 75%    1006.75000       80.750000    76.000000         77.750000
# max    1009.00000       91.000000    98.000000         86.000000

# %%
df
# Out:
#    Rollno    Name  Data Structure  Mathematics  Operating System
# 0    1000  Ananya              80           69                56
# 1    1001    Ravi              74           78                72
# 2    1002   Priya              67           65                86
# 3    1003    Amit              90           98                57
# 4    1004   Sneha              80           96                77
# 5    1005   Kunal              81           70                83
# 6    1006   Divya              42           70                71
# 7    1007  Manish              91           55                43
# 8    1008    Neha              49           62                78
# 9    1009   Rahul              63           69                49

# %%
df.drop(index = 4, axis = 1, inplace=True)

# %%
df
# Out:
#    Rollno    Name  Data Structure  Mathematics  Operating System
# 0    1000  Ananya              80           69                56
# 1    1001    Ravi              74           78                72
# 2    1002   Priya              67           65                86
# 3    1003    Amit              90           98                57
# 5    1005   Kunal              81           70                83
# 6    1006   Divya              42           70                71
# 7    1007  Manish              91           55                43
# 8    1008    Neha              49           62                78
# 9    1009   Rahul              63           69                49

# %%
df.describe()
# Out:
#             Rollno  Data Structure  Mathematics  Operating System
# count   248.000000      248.000000   248.000000        248.000000
# mean   1125.467742       70.181452    72.020161         69.814516
# std      71.791132       17.777623    16.074334         17.530017
# min    1000.000000       40.000000    40.000000         40.000000
# 25%    1063.750000       53.750000    60.000000         55.000000
# 50%    1125.500000       70.000000    71.500000         69.000000
# 75%    1187.250000       87.000000    85.250000         86.250000
# max    1249.000000      100.000000   100.000000        100.000000

# %% [markdown]
# # Statical Visualization

# %%
plt.figure(figsize=(10, 6))
plt.plot(df['Name'], df['Data Structure'])
plt.title('Data Structure Marks of Students')
plt.xlabel('Student Name')
plt.ylabel('Marks')
plt.show()
